# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
Petersen = graphs.PetersenGraph()
Petersen
# Out:
# Petersen graph: Graph on 10 vertices

# %%
C23 = graphs.CompleteBipartiteGraph(2,3)
C23
# Out:
# Complete bipartite graph of order 2+3: Graph on 5 vertices

# %%
C5 = graphs.CycleGraph(5)
C5
# Out:
# Cycle graph: Graph on 5 vertices

# %%
C23.all_paths(0,3)
# Out:
# [[0, 2, 1, 3], [0, 3], [0, 4, 1, 3]]

# %%
Petersen.all_paths(0,4)
# Out:
# [[0, 1, 2, 3, 4],
#  [0, 1, 2, 3, 8, 5, 7, 9, 4],
#  [0, 1, 2, 3, 8, 6, 9, 4],
#  [0, 1, 2, 7, 5, 8, 3, 4],
#  [0, 1, 2, 7, 5, 8, 6, 9, 4],
#  [0, 1, 2, 7, 9, 4],
#  [0, 1, 2, 7, 9, 6, 8, 3, 4],
#  [0, 1, 6, 8, 3, 2, 7, 9, 4],
#  [0, 1, 6, 8, 3, 4],
#  [0, 1, 6, 8, 5, 7, 2, 3, 4],
#  [0, 1, 6, 8, 5, 7, 9, 4],
#  [0, 1, 6, 9, 4],
#  [0, 1, 6, 9, 7, 2, 3, 4],
#  [0, 1, 6, 9, 7, 5, 8, 3, 4],
#  [0, 4],
#  [0, 5, 7, 2, 1, 6, 8, 3, 4],
#  [0, 5, 7, 2, 1, 6, 9, 4],
#  [0, 5, 7, 2, 3, 4],
#  [0, 5, 7, 2, 3, 8, 6, 9, 4],
#  [0, 5, 7, 9, 4],
#  [0, 5, 7, 9, 6, 1, 2, 3, 4],
#  [0, 5, 7, 9, 6, 8, 3, 4],
#  [0, 5, 8, 3, 2, 1, 6, 9, 4],
#  [0, 5, 8, 3, 2, 7, 9, 4],
#  [0, 5, 8, 3, 4],
#  [0, 5, 8, 6, 1, 2, 3, 4],
#  [0, 5, 8, 6, 1, 2, 7, 9, 4],
#  [0, 5, 8, 6, 9, 4],
#  [0, 5, 8, 6, 9, 7, 2, 3, 4]]

# %%
G = C23.disjoint_union(C5)
G
# Out:
# Complete bipartite graph of order 2+3 disjoint_union Cycle graph: Graph on 10 vertices

# %%
G.all_paths((0,4),(1,0))
# Out:
# []

# %%
graphs.PappusGraph().show(method="js")

# %%
C23.diameter()
C23.radius()
# Out:
# 2
# 2

# %%
R = graphs.RandomRegular(3,12)
R
R.diameter()
R.radius()
# Out:
# Graph on 12 vertices
# 4
# 3

# %%
graphs.RandomRegular(3,8).show(method="js")
